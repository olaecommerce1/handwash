# %% [markdown]
# # 1. Data Preperation

# %%
import requests
import tarfile
import os
import random
import cv2
from pathlib import Path

# %%
# Function to download a file from a URL
def download_file(url, filename):
    print("Getting the dataset...")
    r = requests.get(url, stream=True)
    with open(filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=128):
            f.write(chunk)
    print("Dataset downloaded.")

dataset_url = "https://github.com/atiselsts/data/raw/master/kaggle-dataset-6classes.tar"
dataset_filename = "kaggle-dataset-6classes.tar"
download_file(dataset_url, dataset_filename)

# %%
# Function to extract a tar file
def extract_tar(filename):
    print("Extracting the dataset...")
    with tarfile.open(filename) as tar:
        tar.extractall()
    print("Dataset extracted.")
    
extract_tar(dataset_filename)

# %%
# Function to process videos and separate frames
def process_videos_and_frames():
    TEST_PROPORTION = 0.3
    input_dir = './kaggle-dataset-6classes'
    output_videos_dir = './kaggle-dataset-6classes-preprocessed/videos'
    output_frames_dir = './kaggle-dataset-6classes-preprocessed/frames'
    N_CLASSES = 7
    subdirs = [str(i) for i in range(N_CLASSES)]

    def mk(directory):
        Path(directory).mkdir(parents=True, exist_ok=True)

    def process_video(classdir, filename, target_subset):
        input_fullname = os.path.join(input_dir, classdir, filename)
        output_fullname = os.path.join(output_videos_dir, target_subset, classdir, filename)
        print(input_fullname, "->", target_subset)

        # Copy video file to the target directory
        os.makedirs(os.path.dirname(output_fullname), exist_ok=True)
        with open(input_fullname, "rb") as f_in:
            with open(output_fullname, "wb") as f_out:
                f_out.write(f_in.read())

        # Process frames
        vidcap = cv2.VideoCapture(input_fullname)
        success, image = vidcap.read()
        frame_number = 0
        while success:
            out_filename = f"frame_{frame_number}_{os.path.splitext(filename)[0]}.jpg"
            save_path_and_name = os.path.join(output_frames_dir, target_subset, classdir, out_filename)
            os.makedirs(os.path.dirname(save_path_and_name), exist_ok=True)
            cv2.imwrite(save_path_and_name, image)
            success, image = vidcap.read()
            frame_number += 1

    random.seed(123)  # make it repeatable

    # Prepare directories
    for movement in range(N_CLASSES):
        mk(os.path.join(output_videos_dir, "test", str(movement)))
        mk(os.path.join(output_videos_dir, "trainval", str(movement)))
        mk(os.path.join(output_frames_dir, "test", str(movement)))
        mk(os.path.join(output_frames_dir, "trainval", str(movement)))

    # Process each video file
    for classdir in subdirs:
        for filename in os.listdir(os.path.join(input_dir, classdir)):
            if ".mp4" not in filename:
                continue
            target_subset = "test" if random.random() < TEST_PROPORTION else "trainval"
            process_video(classdir, filename, target_subset)

    print("Preprocessing complete.")
    
# Now process the videos and frames
process_videos_and_frames()
# Out:
# ./kaggle-dataset-6classes\0\HandWash_001_A_11_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_001_A_12_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_002_A_11_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_002_A_12_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_003_A_11_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_003_A_12_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_004_A_11_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_004_A_12_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_005_A_11_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_005_A_12_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_006_A_11_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_006_A_12_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_007_A_11_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_007_A_12_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_008_A_11_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_008_A_12_G_01.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_009_A_11_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_009_A_12_G_02.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_010_A_11_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_010_A_12_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_011_A_11_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_011_A_12_G_02.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_012_A_11_G_03.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_012_A_12_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_013_A_11_G_03.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_013_A_12_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_014_A_11_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_014_A_12_G_03.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_015_A_11_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_015_A_12_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_016_A_11_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_016_A_12_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_017_A_11_G_04.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_017_A_12_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_018_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_018_A_12_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_019_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_019_A_12_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_020_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_020_A_12_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_021_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_021_A_12_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_022_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_022_A_12_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_023_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_023_A_12_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_024_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_024_A_12_G_05.mp4 -> test
# ./kaggle-dataset-6classes\0\HandWash_025_A_11_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\0\HandWash_025_A_12_G_05.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_001_A_01_G01.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_002_A_01_G01.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_003_A_01_G01.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_004_A_01_G01.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_005_A_01_G01.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_006_A_01_G01.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_007_A_01_G01.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_008_A_01_G01.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_009_A_01_G02.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_010_A_01_G02.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_011_A_01_G02.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_012_A_01_G03.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_013_A_01_G03.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_014_A_01_G03.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_015_A_01_G04.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_016_A_01_G04.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_017_A_01_G04.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_018_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_019_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_020_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_021_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_022_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_023_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\1\HandWash_024_A_01_G05.mp4 -> test
# ./kaggle-dataset-6classes\1\HandWash_025_A_01_G05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_001_A_02_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_001_A_03_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_002_A_02_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_002_A_03_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_003_A_02_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_003_A_03_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_004_A_02_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_004_A_03_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_005_A_02_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_005_A_03_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_006_A_02_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_006_A_03_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_007_A_02_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_007_A_03_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_008_A_02_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_008_A_03_G_01.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_009_A_02_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_009_A_03_G_02.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_010_A_02_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_010_A_03_G_02.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_011_A_02_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_011_A_03_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_012_A_02_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_012_A_03_G_03.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_013_A_02_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_013_A_03_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_014_A_02_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_014_A_03_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_015_A_02_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_015_A_03_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_016_A_02_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_016_A_03_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_017_A_02_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_017_A_03_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_018_A_02_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_018_A_03_G_05.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_019_A_02_G_05.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_019_A_03_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_020_A_02_G_05.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_020_A_03_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_021_A_02_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_021_A_03_G_05.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_022_A_02_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_022_A_03_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_023_A_02_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_023_A_03_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_024_A_02_G_05.mp4 -> test
# ./kaggle-dataset-6classes\2\HandWash_024_A_03_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_025_A_02_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\2\HandWash_025_A_03_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_001_A_04_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_002_A_04_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_003_A_04_G_01.mp4 -> test
# ./kaggle-dataset-6classes\3\HandWash_004_A_04_G_01.mp4 -> test
# ./kaggle-dataset-6classes\3\HandWash_005_A_04_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_006_A_04_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_007_A_04_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_008_A_04_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_009_A_04_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_010_A_04_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_011_A_04_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_012_A_04_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_013_A_04_G_03.mp4 -> test
# ./kaggle-dataset-6classes\3\HandWash_014_A_04_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_015_A_04_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_016_A_04_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_017_A_04_G_04.mp4 -> test
# ./kaggle-dataset-6classes\3\HandWash_018_A_04_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_019_A_04_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_020_A_04_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_021_A_04_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_022_A_04_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_023_A_04_G_05.mp4 -> test
# ./kaggle-dataset-6classes\3\HandWash_024_A_04_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\3\HandWash_025_A_04_G_05.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_001_A_05_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_001_A_06_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_002_A_05_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_002_A_06_G_01.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_003_A_05_G_01.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_003_A_06_G_01.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_004_A_05_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_004_A_06_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_005_A_05_G_01.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_005_A_06_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_006_A_05_G_01.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_006_A_06_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_007_A_05_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_007_A_06_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_008_A_05_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_008_A_06_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_009_A_05_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_009_A_06_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_010_A_05_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_010_A_06_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_011_A_05_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_011_A_06_G_02.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_012_A_05_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_012_A_06_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_013_A_05_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_013_A_06_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_014_A_05_G_03.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_014_A_06_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_015_A_05_G_04.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_015_A_06_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_016_A_05_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_016_A_06_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_017_A_05_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_017_A_06_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_018_A_05_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_018_A_06_G_05.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_019_A_05_G_05.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_019_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_020_A_05_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_020_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_021_A_05_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_021_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_022_A_05_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_022_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_023_A_05_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_023_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_024_A_05_G_05.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_024_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\4\HandWash_025_A_05_G_05.mp4 -> test
# ./kaggle-dataset-6classes\4\HandWash_025_A_06_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_001_A_07_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_001_A_08_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_002_A_07_G_01.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_002_A_08_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_003_A_07_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_003_A_08_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_004_A_07_G_01.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_004_A_08_G_01.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_005_A_07_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_005_A_08_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_006_A_07_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_006_A_08_G_01.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_007_A_07_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_007_A_08_G_01.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_008_A_07_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_008_A_08_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_009_A_07_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_009_A_08_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_010_A_07_G_02.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_010_A_08_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_011_A_07_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_011_A_08_G_02.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_012_A_07_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_012_A_08_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_013_A_07_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_013_A_08_G_03.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_014_A_07_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_014_A_08_G_03.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_015_A_07_G_04.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_015_A_08_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_016_A_07_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_016_A_08_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_017_A_07_G_04.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_017_A_08_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_018_A_07_G_05.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_018_A_08_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_019_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_019_A_08_G_05.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_020_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_020_A_08_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_021_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_021_A_08_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_022_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_022_A_08_G_05.mp4 -> test
# ./kaggle-dataset-6classes\5\HandWash_023_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_023_A_08_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_024_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_024_A_08_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_025_A_07_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\5\HandWash_025_A_08_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_001_A_09_G_01.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_001_A_10_G_01.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_002_A_09_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_002_A_10_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_003_A_09_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_003_A_10_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_004_A_09_G_01.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_004_A_10_G_01.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_005_A_09_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_005_A_10_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_006_A_09_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_006_A_10_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_007_A_09_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_007_A_10_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_008_A_09_G_01.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_008_A_10_G_01.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_009_A_09_G_02.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_009_A_10_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_010_A_09_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_010_A_10_G_02.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_011_A_09_G_02.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_011_A_10_G_02.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_012_A_09_G_03.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_012_A_10_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_013_A_09_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_013_A_10_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_014_A_09_G_03.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_014_A_10_G_03.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_015_A_09_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_015_A_10_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_016_A_09_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_016_A_10_G_04.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_017_A_09_G_04.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_017_A_10_G_04.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_018_A_09_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_018_A_10_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_019_A_09_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_019_A_10_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_020_A_09_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_020_A_10_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_021_A_09_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_021_A_10_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_022_A_09_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_022_A_10_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_023_A_09_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_023_A_10_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_024_A_09_G_05.mp4 -> trainval
# ./kaggle-dataset-6classes\6\HandWash_024_A_10_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_025_A_09_G_05.mp4 -> test
# ./kaggle-dataset-6classes\6\HandWash_025_A_10_G_05.mp4 -> test
# Preprocessing complete.
