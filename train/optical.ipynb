# %% [markdown]
# # Optical Flow

# %%
import os
import cv2 as cv
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed

# %%
N_CLASSES = 7
classes = [str(i) for i in range(N_CLASSES)]

def mk(filename):
    if not os.path.exists(filename):
        os.makedirs(filename, exist_ok=True)

def read_frames(video_filename):
    cap = cv.VideoCapture(video_filename)
    frames = []
    ret, frame = cap.read()
    while ret:
        gray = cv.cvtColor(frame, cv.COLOR_BGR2GRAY)
        frames.append(gray)
        ret, frame = cap.read()
    cap.release()
    return frames

def frame_sequence_to_flow(f1, f2):
    flow = cv.calcOpticalFlowFarneback(f1, f2, None, 0.5, 3, 15, 3, 5, 1.2, 0)
    magnitude, angle = cv.cartToPolar(flow[..., 0], flow[..., 1])
    mask = np.zeros((len(f1), len(f1[0]), 3), dtype=np.float32)
    mask[..., 0] = angle * 180 / np.pi / 2
    mask[..., 1] = 255
    mask[..., 2] = cv.normalize(magnitude, None, 0, 255, cv.NORM_MINMAX)
    rgb = cv.cvtColor(mask, cv.COLOR_HSV2BGR)
    return rgb

def extract_flow(input_dir, output_dir, c, filename, frame_step):
    in_fullname = os.path.join(input_dir, c, filename)
    out_fullname = os.path.join(output_dir, c, "frame_{}_" + os.path.splitext(filename)[0] + ".jpg")

    print("processing", in_fullname)
    frames = read_frames(in_fullname)
    n = len(frames)
    flow_frame_num = 0

    for i in range(n - frame_step):
        frame1 = frames[i]
        frame2 = frames[i + frame_step]
        flow_frame = frame_sequence_to_flow(frame1, frame2)
        save_path_and_name = out_fullname.format(flow_frame_num)
        flow_frame_num += 1
        cv.imwrite(save_path_and_name, flow_frame)
        
    return in_fullname  # Return the processed filename for verification

def process_videos(input_dir, output_dir, c, filenames, frame_step):
    for filename in filenames:
        if filename.endswith(".mp4"):
            extract_flow(input_dir, output_dir, c, filename, frame_step)

def process_dataset(dataset_dir, FPS=16, frame_step=None, max_workers=8):
    frame_step = frame_step or (FPS // 3)
    executor = ThreadPoolExecutor(max_workers=max_workers)

    for partition in ["test", "trainval"]:
        input_dir = os.path.join(dataset_dir, "videos", partition)
        output_dir = os.path.join(dataset_dir, "of", partition)
        
        mk(output_dir)
        for c in classes:
            mk(os.path.join(output_dir, c))
            class_dir = os.path.join(input_dir, c)
            filenames = os.listdir(class_dir)

            # Using ThreadPoolExecutor to process videos in parallel
            future_to_video = {executor.submit(process_videos, input_dir, output_dir, c, [filename], frame_step): filename for filename in filenames if filename.endswith(".mp4")}
            
            for future in as_completed(future_to_video):
                url = future_to_video[future]
                try:
                    data = future.result()
                except Exception as exc:
                    print('%r generated an exception: %s' % (url, exc))

# %%
dataset_dir = 'kaggle-dataset-6classes-preprocessed'
process_dataset(dataset_dir)
# Out:
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_001_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_001_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_002_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_003_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_005_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_007_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_007_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_008_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_009_A_12_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_011_A_12_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_012_A_11_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_013_A_11_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_014_A_12_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_017_A_11_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_024_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\0\HandWash_025_A_12_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_007_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_011_A_01_G02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_012_A_01_G03.mp4
#  kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_004_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_014_A_01_G03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_016_A_01_G04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\1\HandWash_024_A_01_G05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_003_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_003_A_03_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_001_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_004_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_004_A_03_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_005_A_03_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_007_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_007_A_03_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_008_A_03_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_009_A_03_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_010_A_03_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_012_A_03_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_018_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_019_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_020_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_021_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\2\HandWash_024_A_02_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\test\3\HandWash_004_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\3\HandWash_013_A_04_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\3\HandWash_017_A_04_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\3\HandWash_023_A_04_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\3\HandWash_025_A_04_G_05.mp4
#  kaggle-dataset-6classes-preprocessed\videos\test\3\HandWash_003_A_04_G_01.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_003_A_05_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_003_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_005_A_05_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_006_A_05_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_002_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_011_A_06_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_014_A_05_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_015_A_05_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_018_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_019_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_024_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\4\HandWash_025_A_05_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_004_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_004_A_08_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_006_A_08_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_007_A_08_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_002_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_010_A_07_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_011_A_08_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_013_A_08_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_014_A_08_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_015_A_07_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_017_A_07_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_018_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_019_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_022_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\5\HandWash_025_A_08_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_001_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_004_A_09_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_001_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_004_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_008_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_009_A_09_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_010_A_10_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_011_A_09_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_012_A_09_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_014_A_09_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_017_A_09_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_017_A_10_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_018_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_018_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_019_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_020_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_022_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_024_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_025_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\test\6\HandWash_025_A_10_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_003_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_004_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_004_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_005_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_006_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_006_A_12_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_008_A_11_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_002_A_11_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_009_A_11_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_010_A_11_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_010_A_12_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_011_A_11_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_012_A_12_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_013_A_12_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_014_A_11_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_015_A_11_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_015_A_12_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_016_A_11_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_016_A_12_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_017_A_12_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_018_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_018_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_019_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_019_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_020_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_020_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_021_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_021_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_022_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_022_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_023_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_023_A_12_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_024_A_11_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\0\HandWash_025_A_11_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_002_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_003_A_01_G01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_001_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_005_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_006_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_008_A_01_G01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_009_A_01_G02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_010_A_01_G02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_013_A_01_G03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_015_A_01_G04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_017_A_01_G04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_018_A_01_G05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_019_A_01_G05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_020_A_01_G05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_021_A_01_G05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_022_A_01_G05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_023_A_01_G05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\1\HandWash_025_A_01_G05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_002_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_002_A_03_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_001_A_03_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_005_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_006_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_006_A_03_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_008_A_02_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_009_A_02_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_010_A_02_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_011_A_02_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_011_A_03_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_012_A_02_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_013_A_02_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_013_A_03_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_014_A_02_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_014_A_03_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_015_A_02_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_015_A_03_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_016_A_02_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_016_A_03_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_017_A_02_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_017_A_03_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_018_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_019_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_020_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_021_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_022_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_022_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_023_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_023_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_024_A_03_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_025_A_02_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\2\HandWash_025_A_03_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_002_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_005_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_006_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_007_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_008_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_009_A_04_G_02.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_001_A_04_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_010_A_04_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_011_A_04_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_012_A_04_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_014_A_04_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_015_A_04_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_016_A_04_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_018_A_04_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_019_A_04_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_020_A_04_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_021_A_04_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_022_A_04_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\3\HandWash_024_A_04_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_001_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_002_A_05_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_001_A_05_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_004_A_05_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_004_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_005_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_006_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_007_A_05_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_007_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_008_A_05_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_008_A_06_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_009_A_05_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_009_A_06_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_010_A_05_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_010_A_06_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_011_A_05_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_012_A_05_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_012_A_06_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_013_A_05_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_013_A_06_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_014_A_06_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_015_A_06_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_016_A_05_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_016_A_06_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_017_A_05_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_017_A_06_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_018_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_019_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_020_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_020_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_021_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_021_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_022_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_022_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_023_A_05_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_023_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_024_A_06_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\4\HandWash_025_A_06_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_001_A_08_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_002_A_08_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_001_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_003_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_003_A_08_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_005_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_005_A_08_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_006_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_007_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_008_A_07_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_008_A_08_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_009_A_07_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_009_A_08_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_010_A_08_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_011_A_07_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_012_A_07_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_012_A_08_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_013_A_07_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_014_A_07_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_015_A_08_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_016_A_07_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_016_A_08_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_017_A_08_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_018_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_019_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_020_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_020_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_021_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_021_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_022_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_023_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_023_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_024_A_07_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_024_A_08_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\5\HandWash_025_A_07_G_05.mp4
# processingprocessing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_002_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_003_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_003_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_005_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_005_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_006_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_006_A_10_G_01.mp4
#  kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_002_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_007_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_007_A_10_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_008_A_09_G_01.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_009_A_10_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_010_A_09_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_011_A_10_G_02.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_012_A_10_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_013_A_09_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_013_A_10_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_014_A_10_G_03.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_015_A_09_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_015_A_10_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_016_A_09_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_016_A_10_G_04.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_019_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_020_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_021_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_021_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_022_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_023_A_09_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_023_A_10_G_05.mp4
# processing kaggle-dataset-6classes-preprocessed\videos\trainval\6\HandWash_024_A_09_G_05.mp4
